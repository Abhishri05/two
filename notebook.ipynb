# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
data = pd.read_csv('dim_date.csv')

# %%
data.tail()
# Out:
#     date_sk        date  day  month month_name  quarter  year  day_of_week  \
# 85       86  2025-03-27   27      3      March        1  2025            4
# 86       87  2025-03-28   28      3      March        1  2025            5
# 87       88  2025-03-29   29      3      March        1  2025            6
# 88       89  2025-03-30   30      3      March        1  2025            7
# 89       90  2025-03-31   31      3      March        1  2025            1
#
#     day_name  is_weekend  is_month_end  is_month_start  is_quarter_end  \
# 85  Thursday       False         False           False           False
# 86    Friday       False         False           False           False
# 87  Saturday        True         False           False           False
# 88    Sunday        True         False           False           False
# 89    Monday       False          True           False            True
#
#     is_quarter_start
# 85             False
# 86             False
# ...

# %%
print("Goodbye, World!")
